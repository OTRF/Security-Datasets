# %% [markdown]
# # RDP TaskManager LSASS Dump

# %% [markdown]
# ## Metadata

# %% [markdown]
# |                   |    |
# |:------------------|:---|
# | Author            | Roberto Rodriguez @Cyb3rWard0g |
# | Creation Date     | 2019/10/27 |
# | Modification Date | 2020/09/21 |
# | Tactics           | ['[TA0006](https://attack.mitre.org/tactics/TA0006)'] |
# | Techniques        | ['[T1003.001](https://attack.mitre.org/techniques/T1003/001)'] |
# | Tags              | ['RDP Interactive'] |

# %% [markdown]
# ## Dataset Description
# This dataset represents adversaries using RDP and task manager interactively and dump the memory space of lsass.

# %% [markdown]
# ## Datasets Downloads

# %% [markdown]
# | Dataset Type | Link   |
# |:-------------|:---|
#
# | Dataset Host           | [https://raw.githubusercontent.com/OTRF/mordor/master/small_datasets/windows/credential_access/host/rdp_interactive_taskmanager_lsass_dump.zip](https://raw.githubusercontent.com/OTRF/mordor/master/small_datasets/windows/credential_access/host/rdp_interactive_taskmanager_lsass_dump.zip) |

# %% [markdown]
# ## Notebooks
# Notebooks created by the community leveraging the mordor datasets

# %% [markdown]
# | Author | Name | Link |
# |:-------|:-----|:-----|
# | Threat Hunter Playbook | Remote Interactive Task Manager LSASS Dump | [https://threathunterplaybook.com/notebooks/windows/06_credential_access/credential_access/WIN-191030201010.html](https://threathunterplaybook.com/notebooks/windows/06_credential_access/credential_access/WIN-191030201010.html) |

# %% [markdown]
# ## Simulation Plan

# %% [markdown]
# | Environment | Tool Type | Module |
# |:------------|:----------|:-------|
# | Mordor shire | Interactive Session | [None](None) |

# %% [markdown]
# ## Adversary View
# ```
# RDP to victim
# Open Windows Task Manager as Administrator
# Select lsass.exe
# Right-click on lsass.exe and select “Create dump file”
# ```

# %% [markdown]
# ## Explore Mordor Dataset

# %% [markdown]
# ### Initialize Analytics Engine

# %%
from openhunt.mordorutils import *
spark = get_spark()

# %% [markdown]
# ### Download & Process Mordor File

# %%
mordor_file = "https://raw.githubusercontent.com/OTRF/mordor/master/small_datasets/windows/credential_access/host/rdp_interactive_taskmanager_lsass_dump.zip"
registerMordorSQLTable(spark, mordor_file, "mordorTable")

# %% [markdown]
# ### Get to know your data

# %%
df = spark.sql(
'''
SELECT Hostname,Channel,EventID, Count(*) as count
FROM mordorTable
GROUP BY Hostname,Channel,EventID
ORDER BY count DESC
'''
)
df.show(truncate=False)
